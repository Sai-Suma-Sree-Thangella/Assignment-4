# %%
import pandas as pd
df=pd.read_csv('data.csv')
df.describe() #Basic statistical description of the data
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df.isnull().sum() #checking if there are any null values
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df['Calories'].fillna(df['Calories'].mean(),inplace=True)# replacing the null values with mean
df['Calories'].isnull().sum() #checking if null still exists
# Out:
# 0

# %%
df.groupby(['Maxpulse','Calories']).agg({'Duration':['min','max','count','mean'],'Pulse':['min','max','count','mean']})#aggregation of duration,pulse using calories and Maxpulse
# Out:
#                   Duration                   Pulse
#                        min  max count   mean   min  max count   mean
# Maxpulse Calories
# 100      50.5           15   15     1   15.0    80   80     1   80.0
#          500.0          90   90     1   90.0    90   90     1   90.0
#          500.4          90   90     1   90.0    90   90     1   90.0
# 101      300.0          60   60     1   60.0   130  130     1  130.0
# 103      242.0          45   45     1   45.0   129  129     1  129.0
# ...                    ...  ...   ...    ...   ...  ...   ...    ...
# 172      226.4          20   20     1   20.0   153  153     1  153.0
# 175      238.0          30   30     1   30.0   136  136     1  136.0
#          282.4          45   45     1   45.0   109  109     1  109.0
# 182      319.2          30   30     1   30.0   159  159     1  159.0
# 184      1860.4        210  210     1  210.0   137  137     1  137.0
#
# [161 rows x 8 columns]

# %%
df[(df['Calories'].between(500,1000))]#calories between 500 and 1000 data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 83        120    100       130     500.0
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df[(df['Calories'] > 500) & (df['Pulse'] <= 100)]#calories >500 and pulse<100 data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 79        270    100       131    1729.0
# 87        120    100       157    1000.1
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df_modified=df.loc[:,df.columns!='Maxpulse']
df_modified#df without maxpulse
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
df.drop('Maxpulse',axis=1) #detlting Maxpulse in the main df
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
df['Calories']=df['Calories'].astype(int)#converting the data type to int
type(df['Calories'][0])
# Out:
# numpy.int32

# %%
df.plot.scatter(x='Duration',y='Calories') #scatter plot
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>

# %%
sdf=pd.read_csv('Salary_Data.csv')
sdf.describe()#salary data description
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(sdf.iloc[:, :-1].values,sdf.iloc[:,1].values,test_size =0.2)
x_train#checking train data
# Out:
# array([[ 2.9],
#        [ 3. ],
#        [ 9. ],
#        [ 1.3],
#        [ 8.7],
#        [ 5.3],
#        [ 8.2],
#        [ 1.5],
#        [ 6.8],
#        [ 7.1],
#        [ 3.7],
#        [10.3],
#        [ 3.2],
#        [10.5],
#        [ 4. ],
#        [ 5.9],
#        [ 2. ],
#        [ 6. ],
#        [ 9.5],
#        [ 3.9],
#        [ 1.1],
#        [ 4.1],
#        [ 5.1],
#        [ 4. ]])

# %%
from sklearn.linear_model import LinearRegression
m=LinearRegression()#linearregression
m.fit(x_train, y_train)#fitting the data for the linear regression
# Out:
# LinearRegression()

# %%
y_pred=m.predict(x_test)#predicting the data for testing using the uilt model
#y_pred*z+min(sdf['Salary'])

# %%
import math
from sklearn.metrics import mean_squared_error as ms
ms(y_pred,y_test)#mean square error
# Out:
# 30604958.80794136

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train)

# %%
plt.scatter(x_test,y_test)
